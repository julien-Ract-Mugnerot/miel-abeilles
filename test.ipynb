# %%
import math
import random as r
import statistics
import os
import copy
import random
import ast
from treelib import Node, Tree
from graphviz import Digraph
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from beehive import Honeycomb

# from beehive import *

# Cela devrait prendre 20-30 secondes avec les paramètres de tests rapides actuels.
nest1 = Honeycomb(csv_path='Champ de pissenlits et de sauge des pres.xlsx')



# Cela devrait prendre 2-3 minutes avec les paramètres par défaut sur lequels
# la présentation à été réalisée.
# nest2 = Honeycomb(csv_path='Champ de pissenlits et de sauge des pres.csv',\
#                  quantity = 50, loops=3000, steps = [3, 4], mutations = [1, 2, 4], \
#                  mutations_starts = [500, 1000, 1, 2000] ,mut_status = True, topXBees = 25)
# Out:
# /home/julienrm/code/plateforme/La_plateforme_Ract-Mugnerot_Julien/bees/miel-abeilles/beehive.py:326: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.honeycomb_df['pos'][bee_index] = self.honeycomb_df['pos'][top_bee_index]
# /home/julienrm/code/plateforme/La_plateforme_Ract-Mugnerot_Julien/bees/miel-abeilles/beehive.py:341: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.honeycomb_df['pos'][flow1_id], self.honeycomb_df['pos'][flow2_id] = \
# /home/julienrm/.pyenv/versions/3.8.12/envs/lewagon/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# ...

# %%
# L'arbre génalogique peut être petit sur une courte simulation comme celle-ci !
Image(filename='tree_plots/tree_plot.png')
