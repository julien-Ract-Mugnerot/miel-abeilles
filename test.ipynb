# %%
import math
import random as r
import statistics
import os
import copy
import random
import ast
from treelib import Node, Tree
from graphviz import Digraph
from IPython.display import Image
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import seaborn as sns
from beehive import Honeycomb

# from beehive import *


nest1 = Honeycomb(csv_path='Champ de pissenlits et de sauge des pres.xlsx')
# nest1.best_score
# Image(filename='tree_plots/tree_plot.png')
# nest1.display_ft()
# nest1.plot_best_saved_score()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_8217/3464248217.py in <module>
#      20
#      21
# ---> 22 nest1 = Honeycomb(csv_path='Champ de pissenlits et de sauge des pres.xlsx')
#      23 # nest1.best_score
#      24 # Image(filename='tree_plots/tree_plot.png')
#
# ~/code/plateforme/La_plateforme_Ract-Mugnerot_Julien/bees/rendu/beehive.py in __init__(self, csv_path, quantity, loops, steps, mutations, mutations_starts, mut_status, topXBees)
#      75         self.bs_df = self.honeycomb_df
#      76         self.honeycomb_score()
# ---> 77         self.centralize()
#      78
#      79     #test
#
# ~/code/plateforme/La_plateforme_Ract-Mugnerot_Julien/bees/rendu/beehive.py in centralize(self)
#      93         self.save_df()
#      94         #Plot Results
# ---> 95         self.plot_path(self.honeycomb_df, self.honeycomb_df['score'][0], 0)
# ...

# %%
# !ls
# Out:
#  beehive.py					  main.py       test.ipynb
#  bee_saves					  plot_saves    tree_plots
# 'Champ de pissenlits et de sauge des pres.csv'	  __pycache__
# 'Champ de pissenlits et de sauge des pres.xlsx'   Readme.md

# %%
plt.plot([4,3,2,1], [1,2,3,4])
